# %% [markdown]
# # Enhancing Our Movie Dataset with Wikipedia and TMDB
#
# In this notebook, we'll enrich our existing movie dataset by gathering additional information from two valuable sources: Wikipedia and The Movie Database (TMDB) API. Many of our movie records have missing information like synopses, budget details, or cast information. We'll address these gaps systematically using web scraping and API techniques.

# %%
import pandas as pd

# %% [markdown]
# ## Loading and Examining Our Dataset
#
# First, we need to understand what data we already have and identify the gaps we need to fill. We'll load our previously scraped movie dataset and examine its structure to identify missing values across different columns.

# %%
df = pd.read_csv("updated_movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   synopsis                        3788 non-null   object
#  1   opening_weekend                 3681 non-null   object
#  2   percent_of_total_gross          3681 non-null   object
#  3   production_budget               3116 non-null   object
#  4   domestic_release_date           3879 non-null   object
#  5   running_time                    4296 non-null   object
#  6   keywords                        4056 non-null   object
#  7   source                          4528 non-null   object
#  8   genre                           4570 non-null   object
#  9   production_method               4568 non-null   object
#  10  creative_type                   4537 non-null   object
#  11  production_financing_companies  3069 non-null   object
#  12  production_countries            4522 non-null   object
#  13  languages                       4356 non-null   object
#  14  lead_ensemble_members           4625 non-null   object
#  15  production_technical_credits    4625 non-null   object
#  16  movie_url                       4625 non-null   object
#  17  movie_title                     4625 non-null   object
# dtypes: object(18)
# memory usage: 650.5+ KB

# %%
df = df.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ## Examining Specific Missing Data
#
# Before implementing our scraping strategy, let's take a closer look at some specific columns with missing data. We're particularly interested in production companies and budget information, as these fields are often incomplete in our original dataset but readily available on Wikipedia and TMDB.

# %%
missing_data = df.isnull().sum().sort_values(ascending=False)
print(missing_data)
# Out:
# production_budget                 1435
# production_financing_companies    1397
# percent_of_total_gross             944
# opening_weekend                    944
# synopsis                           837
# domestic_release_date              746
# keywords                           569
# running_time                       329
# languages                          269
# production_countries               103
# source                              97
# creative_type                       88
# production_method                   57
# genre                               55
# lead_ensemble_members                0
# production_technical_credits         0
# movie_url                            0
# movie_title                          0
# dtype: int64

# %% [markdown]
# ## Setting Up TMDB API Access
#
# To access movie data from The Movie Database (TMDB), we first need to install their Python client library. TMDB provides a comprehensive API that will help us fill in missing synopses and other film details.

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Obtaining dependency information for tmdbv3api from https://files.pythonhosted.org/packages/35/fb/9d575292bb7794a7a85bcdbf6c09928aae5ca2ae9f684f7fbbd902e281c4/tmdbv3api-1.9.0-py3-none-any.whl.metadata
#   Downloading tmdbv3api-1.9.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in /Users/omarbesbes/anaconda3/lib/python3.11/site-packages (from tmdbv3api) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/omarbesbes/anaconda3/lib/python3.11/site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/omarbesbes/anaconda3/lib/python3.11/site-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/omarbesbes/anaconda3/lib/python3.11/site-packages (from requests->tmdbv3api) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/omarbesbes/anaconda3/lib/python3.11/site-packages (from requests->tmdbv3api) (2025.1.31)
# Downloading tmdbv3api-1.9.0-py3-none-any.whl (25 kB)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.9.0

# %% [markdown]
# ## Enriching Synopses using TMDB API
#
# Many of our movie records lack proper synopses, which are crucial for understanding the film's content. Here we'll use the TMDB API to search for movies by title and release year, then extract their plot synopses.
#
# We've implemented careful date parsing logic to ensure we match the correct film, since many movies share similar titles but were released in different years. For each film with a missing synopsis, we'll make an API request, match the release year to confirm we have the right movie, and then update our dataset with the retrieved synopsis.

# %%
from tmdbv3api import TMDb, Movie
import pandas as pd
import time
from datetime import datetime

# TMDB setup
tmdb = TMDb()
tmdb.api_key = "9f3a656bc10a7241687aba82819a8c67"
tmdb.language = "en"
movie_search = Movie()


# Parse your release date format
def parse_our_date(date_str):
    try:
        return datetime.strptime(date_str, "%B %dth, %Y").date()
    except ValueError:
        try:
            return datetime.strptime(date_str, "%B %dst, %Y").date()
        except ValueError:
            try:
                return datetime.strptime(date_str, "%B %dnd, %Y").date()
            except ValueError:
                try:
                    return datetime.strptime(date_str, "%B %drd, %Y").date()
                except ValueError:
                    try:
                        return datetime.strptime(date_str, "%B %d, %Y").date()
                    except:
                        return None


# Get synopsis only if release date matches
def get_synopsis(title, release_date_str):
    our_date = parse_our_date(release_date_str)
    if not our_date:
        return None

    try:
        results = movie_search.search(title)
        for r in results:
            tmdb_date = r.release_date
            if tmdb_date:
                tmdb_parsed = datetime.strptime(tmdb_date, "%Y-%m-%d").date()
                if tmdb_parsed.year == our_date.year:
                    return r.overview
    except Exception as e:
        print(f"Error with {title}: {e}")

    return None


# Only rows where synopsis is missing and we have a release date
mask = df["synopsis"].isnull() & df["domestic_release_date"].notnull()
rows_to_process = df[mask]

for idx, row in rows_to_process.iterrows():
    title = row["movie_title"]
    release_date_str = row["domestic_release_date"]
    synopsis = get_synopsis(title, release_date_str)
    print(title, release_date_str, synopsis)
    if synopsis:
        df.at[idx, "synopsis"] = synopsis
        # print(title,release_date_str,synopsis)
    time.sleep(0.25)  # Respect rate limits
# Out:
# The Perfect Storm June 30th, 2000 In October 1991, a confluence of weather conditions combined to form a killer storm in the North Atlantic. Caught in the storm was the sword-fishing boat Andrea Gail.
# Dolphins October 20th, 2000 From the banks of the Bahamas to the seas of Argentina, we go underwater to meet dolphins. Two scientists who study dolphin communication and behaviour lead us on encounters in the wild. Featuring the music of Sting. Nominated for an Academy Award®, Best Documentary, Short Subject, 2000.
# X-Men July 14th, 2000 While Senator Kelly addresses a senate committee about the supposed mutant menace, we learn about the making of the movie, X-Men.
# Pokemon 2000 July 21st, 2000 A promotional concert/behind the scenes special for the American release of Pokémon: The Movie 2000.
# U-571 April 21st, 2000 In the midst of World War II, the battle under the sea rages and the Nazis have the upper hand as the Allies are unable to crack their war codes. However, after a wrecked U-boat sends out an SOS signal, the Allies realise this is their chance to seize the 'enigma coding machine'.
# Don March 21st, 2019 Juha has lost his wife in an accident. Years after, he still feels numb and unable to connect with people. Meeting Mona, a dominatrix, changes everything.
# Error with Da Yue Zai Dong Ji: 'str' object has no attribute 'release_date'
# Da Yue Zai Dong Ji November 15th, 2019 None
# Error with Shou Yi Ren: 'str' object has no attribute 'release_date'
# Shou Yi Ren November 8th, 2019 None
# Error with Xia Yi Ren: Qian Ren: 'str' object has no attribute 'release_date'
# Xia Yi Ren: Qian Ren May 3rd, 2019 None
# Error with Mei Yanfang (梅艷芳): 'str' object has no attribute 'release_date'
# Mei Yanfang (梅艷芳) November 12th, 2021 None
# Extinct 2021 None
# Ladybug & Cat Noir: The Movie July 21st, 2023 After a guardian of magical jewels turns an awkward girl and a popular boy into superheroes, they can never reveal their identities — even to each other.
# Only the River Flows (河边的错误) July 26th, 2024 None
# Error with Sǎo Dú 3 Rén Zài Tiān Yá (扫毒3:人在天涯)…: 'str' object has no attribute 'release_date'
# Sǎo Dú 3 Rén Zài Tiān Yá (扫毒3:人在天涯)… July 20th, 2023 None
# Devara Part 1 September 27th, 2024 Devara, a fearless man from a coastal region, embarks on a perilous journey into the treacherous world of the sea to safeguard the lives of his people. Unbeknownst to him, his brother Bhaira is plotting a conspiracy against him. As events unfold, Devara passes on his legacy to his mild-mannered and timid son, Varada.
# The Unseen Sister (乔妍的心事) November 8th, 2024 Growing up in a border town, Qiao Yan (Zhao Liying) became a well-known actress after years of hard work, but was careful along the way under heavy pressure. With an anonymous blackmail message, a dusty past becomes her new shadow. Meanwhile, her sister (Xin Zhilei), who lost contact with her years ago, suddenly shows up. Things may seem coincidental, but there is a bigger crisis hidden behind.  The movie is adapted from Zhang Yueran's novel.
# Juror #2 November 1st, 2024 While serving as a juror in a high profile murder trial, family man Justin Kemp finds himself struggling with a serious moral dilemma…one he could use to sway the jury verdict and potentially convict—or free—the accused killer.
# Blue Lock The Movie -Episode Nagi- (劇場版ブルーロック -… June 28th, 2024 When apathetic gamer Nagi agrees to join his rich classmate Mikage in soccer, their partnership leads to the famous Blue Lock program — and to changes.
# Lahn mah September 13th, 2024 M, a university dropout low on money and luck, volunteers to take care of his terminally ill grandmother, in the hope of pocketing an inheritance.
# Error with The Chosen: Season 4 Episodes 1-3: 'str' object has no attribute 'release_date'
# The Chosen: Season 4 Episodes 1-3 February 1st, 2024 None
# Hijack 1971 (하이재킹) July 5th, 2024 Pilots Tae-in and Gyu-sik are set to fly to Gimpo. Under the guidance of flight attendant Ok-soon, passengers are busy boarding. However, shortly after takeoff, a homemade bomb explodes, turning the cabin into chaos.

# %% [markdown]
# ## Saving Our Progress and Examining Updates
#
# After enriching our dataset with TMDB synopses, we'll save the intermediate results to a CSV file and examine a sample of the updated records. This ensures we don't lose our progress if something goes wrong in subsequent steps, and it allows us to verify that the synopsis enrichment worked correctly.

# %%
df.to_csv("updated_movies2.csv", index=False)

# %%
df.head()
# Out:
#                                             synopsis opening_weekend  \
# 0  Greg Focker is ready to marry his girlfriend, ...     $28,623,300
# 1  In October 1991, a confluence of weather condi...     $41,325,042
# 2  From the banks of the Bahamas to the seas of A...             NaN
# 3  Advertising executive Nick Marshall is as cock...     $33,614,543
# 4  When a devious mastermind embroils them in a p...     $40,128,550
#
#   percent_of_total_gross                                  production_budget  \
# 0                  17.2%  $55,000,000 (worldwide box office is 6.0 times...
# 1                  22.6%  $120,000,000 (worldwide box office is 2.7 time...
# 2                    NaN                                                NaN
# 3                  18.4%  $65,000,000 (worldwide box office is 5.8 times...
# 4                  32.0%  $90,000,000 (worldwide box office is 2.9 times...
#
#   domestic_release_date running_time  \
# 0     October 6th, 2000  108 minutes
# 1       June 30th, 2000  129 minutes
# 2    October 20th, 2000   39 minutes
# 3   December 15th, 2000  126 minutes
# 4    November 3rd, 2000   98 minutes
#
#                                             keywords  \
# 0  In-Laws / Future In-Laws , Frat Pack , Family ...
# 1  Visual Effects , Disaster , Extreme Weather , ...
# 2  Nature Documentary , Underwater , Animal Lead ...
# 3  Romance , Psychics , Battle of the Sexes , Set...
# 4  Visual Effects , Action Comedy , Private Inves...
#
#                           source            genre production_method  \
# 0                 Based on Movie           Comedy       Live Action
# 1  Based on Factual Book/Article            Drama       Live Action
# 2      Based on Real Life Events      Documentary       Live Action
# 3            Original Screenplay  Romantic Comedy       Live Action
# 4                    Based on TV           Action       Live Action
#
#           creative_type                     production_financing_companies  \
# 0  Contemporary Fiction  Universal Pictures , DreamWorks Pictures , Nan...
# 1         Dramatization  Baltimore Spring Creek Pictures , Radiant Prod...
# 2               Factual                       [MacGillivray Freeman Films]
# 3  Contemporary Fiction  Paramount Pictures , Icon Productions , Wind D...
# 4  Contemporary Fiction  Columbia Pictures , Leonard Goldberg , Flower ...
#
#   production_countries languages  \
# 0        United States   English
# 1        United States   English
# 2        United States   English
# 3        United States   English
# 4        United States   English
#
#                                lead_ensemble_members  \
# 0  [{'actor': 'Robert De Niro', 'role': 'Jack Byr...
# 1  [{'actor': 'George Clooney', 'role': 'Captain ...
# 2                                                 []
# 3  [{'actor': 'Mel Gibson', 'role': 'Nick Marshal...
# 4  [{'actor': 'Cameron Diaz', 'role': 'Natalie'},...
#
#                         production_technical_credits  \
# 0  {'Director': ['Jay Roach'], 'Screenwriter': ['...
# 1  {'Director': ['Wolfgang Petersen'], 'Screenwri...
# 2  {'Director': ['Greg MacGillivray'], 'Screenwri...
# 3  {'Director': ['Nancy Meyers'], 'Screenwriter':...
# 4  {'Director': ['McG*'], 'Screenwriter': ['Ryan ...
#
#                                            movie_url        movie_title
# 0  https://www.the-numbers.com/movie/Meet-the-Par...   Meet the Parents
# 1  https://www.the-numbers.com/movie/Perfect-Stor...  The Perfect Storm
# 2  https://www.the-numbers.com/movie/Dolphins-(20...           Dolphins
# 3  https://www.the-numbers.com/movie/What-Women-W...    What Women Want
# 4  https://www.the-numbers.com/movie/Charlies-Ang...   Charlie's Angels

# %% [markdown]
# ## Preparing for Wikipedia Scraping
#
# Now we'll install the necessary packages to help with parsing and displaying table data. This will be useful when examining the results of our Wikipedia data extraction.

# %%
pip install tabulate
# Out:
# Collecting tabulate
#   Obtaining dependency information for tabulate from https://files.pythonhosted.org/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl.metadata
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Building a Wikipedia Data Extraction System
#
# For information that isn't available through TMDB, we'll turn to Wikipedia. Wikipedia articles about films typically contain a wealth of structured information in their infoboxes, including production companies, budget figures, cast lists, and crew credits.
#
# We're creating a comprehensive system that:
# 1. Constructs appropriate Wikipedia page titles (e.g., "Avatar (2009 film)")
# 2. Fetches and parses the HTML content of Wikipedia articles
# 3. Extracts structured data from movie infoboxes
# 4. Formats data into consistent structures for our database
# 5. Handles special cases like monetary values in different currencies
#
# The most complex part is parsing financial information, as Wikipedia lists budgets and box office figures in various formats (e.g., "$25 million" or "₹300 crore"). We've implemented specialized parsing logic to standardize all monetary values to USD.

# %%
import wikipediaapi
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd  # <- Missing import

wiki = wikipediaapi.Wikipedia(user_agent="CoolBot/0.0", language="en")


def build_wikipedia_title(title, year):
    return f"{title} ({year} film)"


def fetch_wikipedia_html(title, year):
    page_title = build_wikipedia_title(title, year)
    page = wiki.page(page_title)
    if page.exists():
        url = page.fullurl
        response = requests.get(url)
        if response.status_code == 200:
            return BeautifulSoup(response.content, "html.parser")
    return None


def is_missing(val):
    try:
        if pd.isna(val) or val is None:
            return True

        # Catch literal "[]", "{}", "nan", etc.
        if isinstance(val, str) and val.strip().lower() in [
            "",
            "[]",
            "{}",
            "nan",
            "none",
        ]:
            return True

        # Empty containers
        if isinstance(val, (list, dict, set)) and len(val) == 0:
            return True

        return False
    except:
        return False


def extract_infobox_data(soup):
    data = {}
    infobox = soup.find("table", class_="infobox vevent")
    if not infobox:
        return data

    for row in infobox.find_all("tr"):
        header = row.find("th")
        value = row.find("td")
        if header and value:
            key = header.get_text(strip=True).lower()

            # If the value is a list (<ul><li>...</li></ul>), extract individual items
            if value.find("ul"):
                items = [li.get_text(strip=True) for li in value.find_all("li")]
                data[key] = items
            else:
                val = value.get_text(separator=", ", strip=True)
                data[key] = val
    return data


def format_financing_companies(info):
    entries = []

    for key in ["productioncompanies", "distributed by"]:
        val = info.get(key)
        if not val:
            continue

        if isinstance(val, list):
            raw_list = val
        else:
            # Clean malformed ref markers like [, 1, ]
            cleaned = re.sub(r"\[\s*,?\s*\w\s*,?\s*\]", "", val)
            raw_list = [v.strip() for v in cleaned.split(",") if v.strip()]

        entries.extend(raw_list)

    return entries if entries else None


def format_technical_credits(info):
    role_map = {
        "directed by": "Director",
        "written by": "Screenwriter",
        "screenplay by": "Screenwriter",
        "story by": "Story Creator",
        "produced by": "Producer",
        "cinematography": "Cinematographer",
        "edited by": "Editor",
        "music by": "Composer",
        "production design": "Production Designer",
        "costume design": "Costume Designer",
        "distributed by": "Distributor",
    }

    credits = {}
    for key, val in info.items():
        std_role = role_map.get(key.lower())
        if not std_role:
            continue

        # Handle lists and strings
        if isinstance(val, list):
            names = [v.strip() for v in val if isinstance(v, str) and v.strip()]
        elif isinstance(val, str):
            names = [v.strip() for v in re.split(r",| and |;| & ", val) if v.strip()]
        else:
            continue  # Skip weird types

        if names:
            credits.setdefault(std_role, []).extend(names)

    return credits if credits else None


def format_cast(info):
    cast_key = next((k for k in ["starring", "cast"] if k in info), None)
    if not cast_key:
        return []

    cast_val = info[cast_key]

    # If it's a list already (from <ul><li>...</li></ul>)
    if isinstance(cast_val, list):
        cast_list = cast_val
    else:
        cast_str = cast_val.replace("\xa0", " ")
        cast_list = [a.strip() for a in cast_str.split(",") if a.strip()]

    parsed_cast = []
    for entry in cast_list:
        match = re.match(r"(.+?)\s+as\s+(.+)", entry, re.IGNORECASE)
        if match:
            actor, role = match.groups()
            parsed_cast.append({"actor": actor.strip(), "role": role.strip()})
        else:
            parsed_cast.append({"actor": entry.strip(), "role": ""})

    return parsed_cast


def parse_money(value):
    """
    Parses money values in various formats and converts to USD (float).
    Supports:
      - $25 million
      - US$13–20 million
      - ₹300 crore → converts to USD
    Returns the value in USD (float), or None if it can't be parsed.
    """
    if not isinstance(value, str):
        return None

    # Remove footnote artifacts like [, 1, ]
    cleaned = re.sub(r"\[\s*,?.*?,?\s*\]", "", value)
    cleaned = cleaned.replace("\xa0", " ").strip()

    # INR CRORE FORMAT
    match = re.search(
        r"(?:₹|Rs\.?)\s*([\d,]+(?:\.\d+)?)(?:\s*[–-]\s*([\d,]+(?:\.\d+)?))?\s*crore",
        cleaned,
        re.IGNORECASE,
    )
    if match:
        try:
            num1 = float(match.group(1).replace(",", ""))
            num2 = match.group(2)
            avg = (num1 + float(num2.replace(",", ""))) / 2 if num2 else num1
            inr_total = avg * 10_000_000
            usd_value = inr_total / 83  # Rough 2025 exchange rate
            return usd_value
        except ValueError:
            return None

    # USD / EURO / GBP FORMAT
    match = re.search(
        r"(?:US\$|\$|€|£)?\s*([\d,.]+)(?:[–-]([\d,.]+))?\s*(million|billion)?",
        cleaned,
        re.IGNORECASE,
    )
    if not match:
        return None

    try:
        num1 = float(match.group(1).replace(",", ""))
        num2 = match.group(2)
        unit = match.group(3)

        if num2:
            num2 = float(num2.replace(",", ""))
            avg = (num1 + num2) / 2
        else:
            avg = num1

        multiplier = 1
        if unit:
            unit = unit.lower()
            if unit == "million":
                multiplier = 1_000_000
            elif unit == "billion":
                multiplier = 1_000_000_000

        return avg * multiplier
    except ValueError:
        return None


def format_budget(info):
    budget_str = info.get("budget")
    if not budget_str:
        return None

    b = parse_money(budget_str)
    if not b:
        return None

    gross = None
    for key in ["box office", "gross revenue"]:
        gross_str = info.get(key)
        if gross_str:
            g = parse_money(gross_str)
            if g:
                gross = g
                break

    formatted_budget = f"${int(b):,}"
    if gross:
        ratio = round(gross / b, 1)
        return f"{formatted_budget} (worldwide box office is {ratio} times production budget)"

    return formatted_budget


def fill_movie_data_from_wiki(row):
    title = row.get("movie_title")
    release_date = row.get("domestic_release_date")
    year = None
    try:
        year = int(re.search(r"\d{4}", release_date).group())
    except:
        return row  # Can't proceed without year

    print(title, year)

    soup = fetch_wikipedia_html(title, year)
    if not soup:
        return row

    info = extract_infobox_data(soup)
    print(info)

    print(row)
    print("********")

    if is_missing(row.get("production_technical_credits")):
        credits = format_technical_credits(info)
        if credits:
            row["production_technical_credits"] = credits

    if is_missing(row.get("lead_ensemble_members")):
        cast = format_cast(info)
        if cast:
            row["lead_ensemble_members"] = cast

    if is_missing(row.get("production_budget")):
        budget = format_budget(info)
        if budget:
            row["production_budget"] = budget

    if is_missing(row.get("production_financing_companies")):
        financing = format_financing_companies(info)
        if financing:
            row["production_financing_companies"] = financing

    print(row)

    return row

# %% [markdown]
# ## Applying Wikipedia Data Extraction to Fill Missing Information
#
# Now we'll apply our Wikipedia extraction system to the movies that still have missing information. We're targeting four key fields:
# - Production budgets
# - Cast members
# - Technical credits (directors, writers, etc.)
# - Production and financing companies
#
# For each movie with missing data in these fields, we'll attempt to locate its Wikipedia page, extract the relevant information, and update our dataset accordingly. This process complements the TMDB data we gathered earlier, creating a more complete picture of each film.

# %%
target_fields = [
    "production_budget",
    "lead_ensemble_members",
    "production_technical_credits",
    "production_financing_companies",
]

# This checks per row if any target column is "missing"
filtered_df = df[
    df[target_fields].apply(lambda row: any(is_missing(v) for v in row), axis=1)
]

for idx, row in filtered_df.iterrows():
    df.loc[idx] = fill_movie_data_from_wiki(row)
    print(f"Updated row {idx}")
    print("-------------------------")
# Out:
# Dolphins 2000
# {'directed by': 'Greg MacGillivray', 'written by': 'Tim Cahill, Stephen Judson', 'narrated by': 'Pierce Brosnan', 'cinematography': 'Greg MacGillivray, Brad Ohlund', 'edited by': 'Stephen Judson', 'music by': 'Sting', 'distributed by': 'MacGillivray Freeman Films', 'release date': ['April\xa014,\xa02000(2000-04-14)'], 'running time': '39 min.', 'country': 'United States', 'language': 'English'}
# synopsis                          From the banks of the Bahamas to the seas of A...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                            October 20th, 2000
# running_time                                                             39 minutes
# keywords                          Nature Documentary , Underwater , Animal Lead ...
# source                                                    Based on Real Life Events
# genre                                                                   Documentary
# production_method                                                       Live Action
# creative_type                                                               Factual
# production_financing_companies                         [MacGillivray Freeman Films]
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Greg MacGillivray'], 'Screenwri...
# movie_url                         https://www.the-numbers.com/movie/Dolphins-(20...
# movie_title                                                                Dolphins
# Name: 2, dtype: object
# ********
# synopsis                          From the banks of the Bahamas to the seas of A...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                            October 20th, 2000
# running_time                                                             39 minutes
# keywords                          Nature Documentary , Underwater , Animal Lead ...
# source                                                    Based on Real Life Events
# genre                                                                   Documentary
# production_method                                                       Live Action
# creative_type                                                               Factual
# production_financing_companies                         [MacGillivray Freeman Films]
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Greg MacGillivray'], 'Screenwri...
# movie_url                         https://www.the-numbers.com/movie/Dolphins-(20...
# movie_title                                                                Dolphins
# Name: 2, dtype: object
# Updated row 2
# -------------------------
# Dungeons and Dragons 2000
# Updated row 8
# -------------------------
# Vertical Limit 2000
# Updated row 10
# -------------------------
# Hollow Man 2000
# Updated row 11
# -------------------------
# Pokemon 2000 2000
# Updated row 13
# -------------------------
# U-571 2000
# Updated row 15
# -------------------------
# Book of Shadows: Blair Witch 2 2000
# Updated row 17
# -------------------------
# Hanging Up 2000
# Updated row 18
# -------------------------
# The Whole Nine Yards 2000
# Updated row 19
# -------------------------
# Small Time Crooks 2000
# Updated row 21
# -------------------------
# Scream 3 2000
# Updated row 26
# -------------------------
# Urban Legends: Final Cut 2000
# Updated row 29
# -------------------------
# Bless the Child 2000
# Updated row 30
# -------------------------
# Titan A.E. 2000
# Updated row 32
# -------------------------
# My Dog Skip 2000
# Updated row 33
# -------------------------
# The Art of War 2000
# Updated row 38
# -------------------------
# The 6th Day 2000
# Updated row 39
# -------------------------
# East is East 2000
# Updated row 40
# -------------------------
# Mission to Mars 2000
# Updated row 42
# -------------------------
# Dude, Where's My Car? 2000
# Updated row 45
# -------------------------
# Romeo Must Die 2000
# Updated row 49
# -------------------------
# Bring it On 2000
# Updated row 50
# -------------------------
# The Skulls 2000
# Updated row 51
# -------------------------
# Nutty Professor II: The Klumps 2000
# Updated row 57
# -------------------------
# Rugrats in Paris 2000
# Updated row 58
# -------------------------
# The Original Kings of Comedy 2000
# Updated row 59
# -------------------------
# The Tigger Movie 2000
# Updated row 60
# -------------------------
# Next Friday 2000
# Updated row 62
# -------------------------
# Men of Honor 2000
# Updated row 65
# -------------------------
# Coyote Ugly 2000
# Updated row 67
# -------------------------
# Return to Me 2000
# Updated row 68
# -------------------------
# Keeping the Faith 2000
# Updated row 74
# -------------------------
# Shanghai Noon 2000
# Updated row 76
# -------------------------
# Dancer in the Dark 2000
# Updated row 79
# -------------------------
# Billy Elliot 2000
# Updated row 81
# -------------------------
# Pay it Forward 2000
# Updated row 82
# -------------------------
# Snatch 2000
# Updated row 85
# -------------------------
# Dracula 2000 2000
# Updated row 87
# -------------------------
# The Replacements 2000
# Updated row 99
# -------------------------
# Pokemon 3: The Movie 2001
# Updated row 100
# -------------------------
# What's the Worst That Could Happen? 2001
# Updated row 101
# -------------------------
# How High 2001
# Updated row 103
# -------------------------
# Scary Movie 2 2001
# Updated row 107
# -------------------------
# American Pie 2 2001
# Updated row 111
# -------------------------
# K-PAX 2001
# Updated row 115
# -------------------------
# Les Rivières Pourpres 2001
# Updated row 117
# -------------------------
# Monster's Ball 2001
# Updated row 122
# -------------------------
# See Spot Run 2001
# Updated row 123
# -------------------------
# Gosford Park 2001
# Updated row 128
# -------------------------
# Jay and Silent Bob Strike Back 2001
# Updated row 134
# -------------------------
# Jurassic Park III 2001
# Updated row 136
# -------------------------
# Legally Blonde 2001
# Updated row 137
# -------------------------
# I Am Sam 2001
# Updated row 138
# -------------------------
# Le Fabuleux destin d\'Amélie Poulain 2001
# Updated row 148
# -------------------------
# Kate and Leopold 2001
# Updated row 156
# -------------------------
# Rush Hour 2 2001
# Updated row 157
# -------------------------
# The Wedding Planner 2001
# Updated row 158
# -------------------------
# Recess: School's Out 2001
# Updated row 161
# -------------------------
# Angel Eyes 2001
# Updated row 163
# -------------------------
# La Pianiste 2002
# Updated row 166
# -------------------------
# In the Bedroom 2001
# Updated row 167
# -------------------------
# Save the Last Dance 2001
# Updated row 168
# -------------------------
# Jimmy Neutron: Boy Genius 2001
# Updated row 173
# -------------------------
# Not Another Teen Movie 2001
# Updated row 174
# -------------------------
# The Royal Tenenbaums 2001
# Updated row 175
# -------------------------
# The Tailor of Panama 2001
# Updated row 178
# -------------------------
# Final Fantasy: The Spirits Within 2001
# Updated row 182
# -------------------------
# Kiss of the Dragon 2001
# Updated row 183
# -------------------------
# Hearts in Atlantis 2001
# Updated row 184
# -------------------------
# Riding in Cars with Boys 2001
# Updated row 186
# -------------------------
# Joe Dirt 2001
# Updated row 188
# -------------------------
# Spy Kids 2001
# Updated row 193
# -------------------------
# Harry Potter and the Sorcerer’s Stone 2001
# Updated row 197
# -------------------------
# Haunted Castle 2001
# {'directed by': 'Ben Stassen', 'written by': 'Ben Stassen, Kurt Frey', 'produced by': 'Ben Stassen, Charlotte Clay Huggins', 'starring': 'Jasper Steverlinck, Kyoko Baertsoen, Harry Shearer', 'cinematography': 'Kommer Kleijn', 'edited by': 'Ben Stassen', 'music by': 'Arid, Lunascape', 'distributed by': 'Ventura Distribution, nWave Pictures', 'release date': ['February\xa023,\xa02001(2001-02-23)'], 'running time': '38 minutes', 'countries': 'Belgium, United States', 'language': 'English', 'box office': '$13,651,656'}
# synopsis                          A young musician and singer named Johnny has b...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                               March 2nd, 2001
# running_time                                                             38 minutes
# keywords                                       Kids Horror , IMAX: DMR , Short Film
# source                                                          Original Screenplay
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                               Fantasy
# production_financing_companies               [Ventura Distribution, nWave Pictures]
# production_countries                                        Belgium , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Jasper Steverlinck', 'role': ''}, ...
# production_technical_credits      {'Director': ['Ben Stassen'], 'Screenwriter': ...
# movie_url                         https://www.the-numbers.com/movie/Haunted-Cast...
# movie_title                                                          Haunted Castle
# Name: 199, dtype: object
# ********
# synopsis                          A young musician and singer named Johnny has b...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                               March 2nd, 2001
# running_time                                                             38 minutes
# keywords                                       Kids Horror , IMAX: DMR , Short Film
# source                                                          Original Screenplay
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                               Fantasy
# production_financing_companies               [Ventura Distribution, nWave Pictures]
# production_countries                                        Belgium , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Jasper Steverlinck', 'role': ''}, ...
# production_technical_credits      {'Director': ['Ben Stassen'], 'Screenwriter': ...
# movie_url                         https://www.the-numbers.com/movie/Haunted-Cast...
# movie_title                                                          Haunted Castle
# Name: 199, dtype: object
# Updated row 199
# -------------------------
# Star Trek: Nemesis 2002
# Updated row 200
# -------------------------
# Snow Dogs 2002
# Updated row 202
# -------------------------
# Undercover Brother 2002
# Updated row 206
# -------------------------
# The Divine Secrets of the Ya-Ya Sisterhood 2002
# Updated row 215
# -------------------------
# The Wild Thornberrys Movie 2002
# Updated row 220
# -------------------------
# Barbershop 2002
# Updated row 223
# -------------------------
# 8 Mile 2002
# Updated row 226
# -------------------------
# The Mothman Prophecies 2002
# Updated row 227
# -------------------------
# Like Mike 2002
# Updated row 234
# -------------------------
# Enough 2002
# Updated row 236
# -------------------------
# Blade 2 2002
# Updated row 243
# -------------------------
# Panic Room 2002
# Updated row 244
# -------------------------
# Jackass: The Movie 2002
# Updated row 251
# -------------------------
# Frida 2002
# {'directed by': 'Julie Taymor', 'screenplay by': ['Clancy Sigal', 'Diane Lake', 'Gregory Nava', 'Anna Thomas'], 'based on': 'Frida: A Biography of Frida Kahlo, by Hayden Herrera', 'produced by': ['Sarah Green', 'Salma Hayek', 'Jay Polstein', 'Lizz Speed', 'Nancy Hardin', 'Lindsay Flickinger', 'Roberto Sneider'], 'starring': ['Salma Hayek', 'Alfred Molina', 'Geoffrey Rush', 'Valeria Golino', 'Mía Maestro', 'Roger Rees'], 'cinematography': 'Rodrigo Prieto', 'edited by': 'Françoise Bonnot', 'music by': 'Elliot Goldenthal', 'productioncompanies': ['Ventanarosa', 'Lions Gate Films'], 'distributed by': 'Miramax Films', 'release dates': ['August\xa029,\xa02002(2002-08-29)(Venice)', 'October\xa025,\xa02002(2002-10-25)(United States)'], 'running time': '123 minutes', 'country': 'United States, [, 1, ]', 'language': 'English', 'budget': '$12 million, [, 2, ]', 'box office': '$56.3 million, [, 3, ]'}
# synopsis                          A biography of artist Frida Kahlo, who channel...
# opening_weekend                                                            $205,996
# percent_of_total_gross                                                         0.8%
# production_budget                 $12,000,000 (worldwide box office is 4.7 times...
# domestic_release_date                                            October 25th, 2002
# running_time                                                            123 minutes
# keywords                                   Biography , Artists , Biographical Drama
# source                                                    Based on Real Life Events
# genre                                                                         Drama
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies       [Ventanarosa, Lions Gate Films, Miramax Films]
# production_countries                                                  United States
# languages                                      English , French , Russian , Spanish
# lead_ensemble_members             [{'actor': 'Salma Hayek', 'role': ''}, {'actor...
# production_technical_credits                                                     {}
# movie_url                         https://www.the-numbers.com/movie/Frida#tab=su...
# movie_title                                                                   Frida
# Name: 252, dtype: object
# ********
# synopsis                          A biography of artist Frida Kahlo, who channel...
# opening_weekend                                                            $205,996
# percent_of_total_gross                                                         0.8%
# production_budget                 $12,000,000 (worldwide box office is 4.7 times...
# domestic_release_date                                            October 25th, 2002
# running_time                                                            123 minutes
# keywords                                   Biography , Artists , Biographical Drama
# source                                                    Based on Real Life Events
# genre                                                                         Drama
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies       [Ventanarosa, Lions Gate Films, Miramax Films]
# production_countries                                                  United States
# languages                                      English , French , Russian , Spanish
# lead_ensemble_members             [{'actor': 'Salma Hayek', 'role': ''}, {'actor...
# production_technical_credits      {'Director': ['Julie Taymor'], 'Screenwriter':...
# movie_url                         https://www.the-numbers.com/movie/Frida#tab=su...
# movie_title                                                                   Frida
# Name: 252, dtype: object
# Updated row 252
# -------------------------
# Stuart Little 2 2002
# Updated row 254
# -------------------------
# Jet Li's Hero 2004
# Updated row 256
# -------------------------
# Peter Pan: Return to Neverland 2002
# Updated row 257
# -------------------------
# Ghost Ship 2002
# {'directed by': 'Steve Beck', 'screenplay by': ['Mark Hanlon', 'John Pogue'], 'story by': 'Mark Hanlon', 'produced by': ['Joel Silver', 'Robert Zemeckis', 'Gilbert Adler'], 'starring': ['Julianna Margulies', 'Ron Eldard', 'Desmond Harrington', 'Isaiah Washington', 'Gabriel Byrne'], 'cinematography': 'Gale Tattersall', 'edited by': 'Roger Barton', 'music by': 'John Frizzell', 'productioncompanies': ['Dark Castle Entertainment', 'Village Roadshow Pictures', 'NPV Entertainment'], 'distributed by': 'Warner Bros. Pictures', 'release date': ['October\xa025,\xa02002(2002-10-25)'], 'running time': '91 minutes', 'country': 'United States', 'language': 'English', 'budget': '$20 million', 'box office': '$68.3 million'}
# synopsis                          In a remote region of the Bering Sea, a boat s...
# opening_weekend                                                         $11,503,423
# percent_of_total_gross                                                        38.2%
# production_budget                 $20,000,000 (worldwide box office is 3.4 times...
# domestic_release_date                                            October 25th, 2002
# running_time                                                             90 minutes
# keywords                          Supernatural , Supernatural Horror , On a Boat...
# source                                                          Original Screenplay
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Village Roadshow Productions , Dark Castle Ent...
# production_countries                                      Australia , United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Steve Beck'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Ghost-Ship#t...
# movie_title                                                              Ghost Ship
# Name: 261, dtype: object
# ********
# synopsis                          In a remote region of the Bering Sea, a boat s...
# opening_weekend                                                         $11,503,423
# percent_of_total_gross                                                        38.2%
# production_budget                 $20,000,000 (worldwide box office is 3.4 times...
# domestic_release_date                                            October 25th, 2002
# running_time                                                             90 minutes
# keywords                          Supernatural , Supernatural Horror , On a Boat...
# source                                                          Original Screenplay
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Village Roadshow Productions , Dark Castle Ent...
# production_countries                                      Australia , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Julianna Margulies', 'role': ''}, ...
# production_technical_credits      {'Director': ['Steve Beck'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Ghost-Ship#t...
# movie_title                                                              Ghost Ship
# Name: 261, dtype: object
# Updated row 261
# -------------------------
# About Schmidt 2002
# Updated row 264
# -------------------------
# About a Boy 2002
# Updated row 265
# -------------------------
# The Hot Chick 2002
# Updated row 274
# -------------------------
# Spy Kids 2: The Island of Lost Dreams 2002
# Updated row 276
# -------------------------
# Big Fat Liar 2002
# Updated row 277
# -------------------------
# Bowling for Columbine 2002
# Updated row 278
# -------------------------
# One Hour Photo 2002
# Updated row 279
# -------------------------
# Hable con ella 2002
# Updated row 281
# -------------------------
# The Master of Disguise 2002
# Updated row 282
# -------------------------
# 8 femmes 2002
# Updated row 285
# -------------------------
# Halloween: Resurrection 2002
# Updated row 291
# -------------------------
# The Banger Sisters 2002
# Updated row 292
# -------------------------
# Y Tu Mamá También 2002
# Updated row 293
# -------------------------
# National Lampoon’s Van Wilder 2002
# Updated row 294
# -------------------------
# The Crocodile Hunter: Collision Course 2002
# Updated row 295
# -------------------------
# Clockstoppers 2002
# Updated row 296
# -------------------------
# Friday After Next 2002
# Updated row 297
# -------------------------
# Swimfan 2002
# Updated row 298
# -------------------------
# Space Station 2002
# Updated row 299
# -------------------------
# Terminator 3: Rise of the Machines 2003
# Updated row 300
# -------------------------
# Updated row 302
# -------------------------
# 2 Fast 2 Furious 2003
# Updated row 306
# -------------------------
# Mona Lisa Smile 2003
# Updated row 310
# -------------------------
# Spy Kids 3-D: Game Over 2003
# Updated row 312
# -------------------------
# Cheaper by the Dozen 2003
# {'directed by': 'Shawn Levy', 'screenplay by': ['Sam Harper', 'Joel Cohen', 'Alec Sokolow'], 'story by': 'Craig Titley', 'based on': ['Frank Bunker Gilbreth Jr.', 'Ernestine Gilbreth Carey'], 'produced by': ['Robert Simonds', 'Michael Barnathan', 'Ben Myron'], 'starring': ['Steve Martin', 'Bonnie Hunt', 'Hilary Duff', 'Tom Welling', 'Piper Perabo'], 'cinematography': 'Jonathan Brown', 'edited by': 'George Folsey Jr.', 'music by': 'Christophe Beck', 'productioncompanies': ['20th Century Fox[1]', 'Robert Simonds Productions[2]'], 'distributed by': '20th Century Fox, [, 1, ]', 'release date': ['December\xa025,\xa02003(2003-12-25)(United States)'], 'running time': '99 minutes, [, 1, ]', 'country': 'United States, [, 1, ]', 'language': 'English', 'budget': '$40 million, [, 3, ]', 'box office': '$190.5 million, [, 3, ]'}
# synopsis                          The Baker brood moves to Chicago after patriar...
# opening_weekend                                                         $27,557,647
# percent_of_total_gross                                                        19.9%
# production_budget                 $40,000,000 (worldwide box office is 4.8 times...
# domestic_release_date                                           December 25th, 2003
# running_time                                                             98 minutes
# keywords                          Family Comedy , Dysfunctional Family , Relatio...
# source                                                                       Remake
# genre                                                                        Comedy
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                               Robert Simonds Company
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Shawn Levy'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Cheaper-by-t...
# movie_title                                                    Cheaper by the Dozen
# Name: 313, dtype: object
# ********
# synopsis                          The Baker brood moves to Chicago after patriar...
# opening_weekend                                                         $27,557,647
# percent_of_total_gross                                                        19.9%
# production_budget                 $40,000,000 (worldwide box office is 4.8 times...
# domestic_release_date                                           December 25th, 2003
# running_time                                                             98 minutes
# keywords                          Family Comedy , Dysfunctional Family , Relatio...
# source                                                                       Remake
# genre                                                                        Comedy
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                               Robert Simonds Company
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Steve Martin', 'role': ''}, {'acto...
# production_technical_credits      {'Director': ['Shawn Levy'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Cheaper-by-t...
# movie_title                                                    Cheaper by the Dozen
# Name: 313, dtype: object
# Updated row 313
# -------------------------
# The Lizzie McGuire Movie 2003
# Updated row 316
# -------------------------
# Shanghai Knights 2003
# Updated row 317
# -------------------------
# The Jungle Book 2 2003
# Updated row 318
# -------------------------
# American Wedding 2003
# Updated row 320
# -------------------------
# The League of Extraordinary Gentlemen 2003
# Updated row 321
# -------------------------
# Scary Movie 3 2003
# Updated row 326
# -------------------------
# Piglet's Big Movie 2003
# Updated row 327
# -------------------------
# How to Lose a Guy in 10 Days 2003
# Updated row 329
# -------------------------
# Good Bye, Lenin! 2004
# Updated row 330
# -------------------------
# Legally Blonde 2: Red, White & Blonde 2003
# Updated row 332
# -------------------------
# Love Actually 2003
# Updated row 334
# -------------------------
# Rugrats Go Wild 2003
# Updated row 335
# -------------------------
# Girl with a Pearl Earring 2003
# Updated row 336
# -------------------------
# Matchstick Men 2003
# Updated row 337
# -------------------------
# Under the Tuscan Sun 2003
# Updated row 339
# -------------------------
# Looney Tunes: Back in Action 2003
# Updated row 340
# -------------------------
# Identity 2003
# {'directed by': 'James Mangold', 'written by': 'Michael Cooney', 'produced by': 'Cathy Konrad', 'starring': ['John Cusack', 'Ray Liotta', 'Amanda Peet', 'Alfred Molina', 'Clea DuVall', 'Rebecca De Mornay', 'John Hawkes', 'John C. McGinley', 'William Lee Scott', 'Jake Busey', 'Pruitt Taylor Vince'], 'cinematography': 'Phedon Papamichael Jr.', 'edited by': 'David Brenner', 'music by': 'Alan Silvestri', 'productioncompanies': 'Columbia Pictures, Konrad Pictures', 'distributed by': 'Sony Pictures Releasing', 'release date': ['April\xa025,\xa02003(2003-04-25)'], 'running time': '90 minutes', 'country': 'United States', 'language': 'English', 'budget': '$28 million, [, 1, ]', 'box office': '$90.3 million, [, 1, ]'}
# synopsis                          Complete strangers stranded at a remote desert...
# opening_weekend                                                         $16,225,263
# percent_of_total_gross                                                        31.1%
# production_budget                 $28,000,000 (worldwide box office is 2.9 times...
# domestic_release_date                                              April 25th, 2003
# running_time                                                             88 minutes
# keywords                          Serial Killer , Mental Illness , Extreme Weath...
# source                                                          Original Screenplay
# genre                                                             Thriller/Suspense
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                                    Columbia Pictures
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['James Mangold'], 'Producer': ['...
# movie_url                         https://www.the-numbers.com/movie/Identity#tab...
# movie_title                                                                Identity
# Name: 345, dtype: object
# ********
# synopsis                          Complete strangers stranded at a remote desert...
# opening_weekend                                                         $16,225,263
# percent_of_total_gross                                                        31.1%
# production_budget                 $28,000,000 (worldwide box office is 2.9 times...
# domestic_release_date                                              April 25th, 2003
# running_time                                                             88 minutes
# keywords                          Serial Killer , Mental Illness , Extreme Weath...
# source                                                          Original Screenplay
# genre                                                             Thriller/Suspense
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                                    Columbia Pictures
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'John Cusack', 'role': ''}, {'actor...
# production_technical_credits      {'Director': ['James Mangold'], 'Producer': ['...
# movie_url                         https://www.the-numbers.com/movie/Identity#tab...
# movie_title                                                                Identity
# Name: 345, dtype: object
# Updated row 345
# -------------------------
# Good Boy! 2003
# Updated row 346
# -------------------------
# Brother Bear 2003
# {'directed by': 'Aaron Blaise, Robert Walker', 'screenplay by': ['Tab Murphy', 'Lorne Cameron', 'David Hoselton', 'Steve Bencich', 'Ron J. Friedman'], 'story by': ['Nathan Greno', 'Stevie Wermers-Skelton', 'Kevin Deters', 'Woody Woodman', 'Thom Enriquez', 'Kevin Harkey', 'Broose Johnson', 'John Norton', 'John Puglisi'], 'produced by': 'Chuck Williams', 'starring': 'Joaquin Phoenix, Jeremy Suarez, Rick Moranis, Dave Thomas, Jason Raize, D. B. Sweeney', 'edited by': 'Tim Mertens', 'music by': 'Phil Collins, Mark Mancina', 'productioncompany': 'Walt Disney Feature Animation', 'distributed by': 'Buena Vista Pictures Distribution, [, a, ]', 'release dates': ['October\xa020,\xa02003(2003-10-20)(New Amsterdam Theatre)', 'November\xa01,\xa02003(2003-11-01)(United States)'], 'running time': '85 minutes', 'country': 'United States', 'languages': 'English, Inuktitut', 'budget': '$46 million, [, 1, ]', 'box office': '$250.4 million, [, 2, ]'}
# synopsis                          When an impulsive boy named Kenai is magically...
# opening_weekend                                                            $291,940
# percent_of_total_gross                                                         0.3%
# production_budget                 $46,000,000 (worldwide box office is 5.4 times...
# domestic_release_date                                            October 24th, 2003
# running_time                                                                    NaN
# keywords                          Coming of Age , Native Americans , Prologue , ...
# source                                                          Original Screenplay
# genre                                                                     Adventure
# production_method                                                    Hand Animation
# creative_type                                                          Kids Fiction
# production_financing_companies                        Walt Disney Animation Studios
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Aaron Blaise', 'Robert Walker']...
# movie_url                         https://www.the-numbers.com/movie/Brother-Bear...
# movie_title                                                            Brother Bear
# Name: 347, dtype: object
# ********
# synopsis                          When an impulsive boy named Kenai is magically...
# opening_weekend                                                            $291,940
# percent_of_total_gross                                                         0.3%
# production_budget                 $46,000,000 (worldwide box office is 5.4 times...
# domestic_release_date                                            October 24th, 2003
# running_time                                                                    NaN
# keywords                          Coming of Age , Native Americans , Prologue , ...
# source                                                          Original Screenplay
# genre                                                                     Adventure
# production_method                                                    Hand Animation
# creative_type                                                          Kids Fiction
# production_financing_companies                        Walt Disney Animation Studios
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Joaquin Phoenix', 'role': ''}, {'a...
# production_technical_credits      {'Director': ['Aaron Blaise', 'Robert Walker']...
# movie_url                         https://www.the-numbers.com/movie/Brother-Bear...
# movie_title                                                            Brother Bear
# Name: 347, dtype: object
# Updated row 347
# -------------------------
# The Rundown 2003
# Updated row 348
# -------------------------
# Whale Rider 2003
# Updated row 350
# -------------------------
# The Recruit 2003
# Updated row 351
# -------------------------
# 21 Grams 2003
# Updated row 354
# -------------------------
# Phone Booth 2003
# Updated row 358
# -------------------------
# Kangaroo Jack 2003
# Updated row 359
# -------------------------
# Calendar Girls 2003
# {'directed by': 'Nigel Cole', 'written by': 'Tim Firth, Juliette Towhidi', 'produced by': 'Suzanne Mackie, Nick Barton', 'starring': ['Helen Mirren', 'Julie Walters', 'Linda Bassett', 'Annette Crosbie', 'Celia Imrie', 'Penelope Wilton'], 'cinematography': 'Ashley Rowe', 'edited by': 'Michael Parker', 'music by': 'Patrick Doyle', 'productioncompanies': 'Touchstone Pictures, Harbour Pictures, [, 1, ]', 'distributed by': 'Buena Vista International', 'release date': ['2\xa0September\xa02003(2003-09-02)'], 'running time': '108 minutes', 'country': 'United Kingdom', 'language': 'English', 'budget': '$10 million, [, 2, ]', 'box office': '$93.4 million, [, 2, ]'}
# synopsis                          Members of a Yorkshire branch of the Women's I...
# opening_weekend                                                            $151,393
# percent_of_total_gross                                                         0.5%
# production_budget                 $10,000,000 (worldwide box office is 9.3 times...
# domestic_release_date                                           December 19th, 2003
# running_time                                                            108 minutes
# keywords                                          Comedy Drama , Cancer , Charities
# source                                                    Based on Real Life Events
# genre                                                                        Comedy
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies               Touchstone Pictures , Harbour Pictures
# production_countries                                 United Kingdom , United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Nigel Cole'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Calendar-Gir...
# movie_title                                                          Calendar Girls
# Name: 366, dtype: object
# ********
# synopsis                          Members of a Yorkshire branch of the Women's I...
# opening_weekend                                                            $151,393
# percent_of_total_gross                                                         0.5%
# production_budget                 $10,000,000 (worldwide box office is 9.3 times...
# domestic_release_date                                           December 19th, 2003
# running_time                                                            108 minutes
# keywords                                          Comedy Drama , Cancer , Charities
# source                                                    Based on Real Life Events
# genre                                                                        Comedy
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies               Touchstone Pictures , Harbour Pictures
# production_countries                                 United Kingdom , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Helen Mirren', 'role': ''}, {'acto...
# production_technical_credits      {'Director': ['Nigel Cole'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Calendar-Gir...
# movie_title                                                          Calendar Girls
# Name: 366, dtype: object
# Updated row 366
# -------------------------
# Winged Migration 2003
# Updated row 368
# -------------------------
# Once Upon a Time in Mexico 2003
# Updated row 375
# -------------------------
# National Security 2003
# {'directed by': 'Dennis Dugan', 'written by': 'Jay Scherick, David Ronn', 'produced by': 'Bobby Newmyer, Jeff Silver, Michael Green', 'starring': ['Martin Lawrence', 'Steve Zahn', 'Colm Feore', 'Bill Duke', 'Eric Roberts'], 'cinematography': 'Oliver Wood', 'edited by': 'Debra Neil-Fisher', 'music by': 'Randy Edelman', 'productioncompany': 'Columbia Pictures', 'distributed by': 'Sony Pictures Releasing', 'release date': ['January\xa017,\xa02003(2003-01-17)'], 'running time': '88 minutes', 'country': 'United States', 'language': 'English', 'box office': '$54.6 million, [, 1, ]'}
# synopsis                          Earl Montgomery, a bombastic police academy re...
# opening_weekend                                                         $14,369,694
# percent_of_total_gross                                                        39.6%
# production_budget                                                               NaN
# domestic_release_date                                            January 17th, 2003
# running_time                                                             88 minutes
# keywords                                       Action Comedy , Smuggler , Buddy Cop
# source                                                          Original Screenplay
# genre                                                                        Action
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                            [Sony Pictures Releasing]
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Martin Lawrence', 'role': ''}, {'a...
# production_technical_credits      {'Director': ['Dennis Dugan'], 'Producer': ['J...
# movie_url                         https://www.the-numbers.com/movie/National-Sec...
# movie_title                                                       National Security
# Name: 377, dtype: object
# ********
# synopsis                          Earl Montgomery, a bombastic police academy re...
# opening_weekend                                                         $14,369,694
# percent_of_total_gross                                                        39.6%
# production_budget                                                               NaN
# domestic_release_date                                            January 17th, 2003
# running_time                                                             88 minutes
# keywords                                       Action Comedy , Smuggler , Buddy Cop
# source                                                          Original Screenplay
# genre                                                                        Action
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies                            [Sony Pictures Releasing]
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Martin Lawrence', 'role': ''}, {'a...
# production_technical_credits      {'Director': ['Dennis Dugan'], 'Producer': ['J...
# movie_url                         https://www.the-numbers.com/movie/National-Sec...
# movie_title                                                       National Security
# Name: 377, dtype: object
# Updated row 377
# -------------------------
# Dreamcatcher 2003
# {'directed by': 'Lawrence Kasdan', 'screenplay by': ['William Goldman', 'Lawrence Kasdan'], 'based on': 'Dreamcatcher, by, Stephen King', 'produced by': ['Lawrence Kasdan', 'Charles Okun', 'Mark Kasdan'], 'starring': ['Morgan Freeman', 'Thomas Jane', 'Jason Lee', 'Damian Lewis', 'Timothy Olyphant', 'Tom Sizemore', 'Donnie Wahlberg'], 'cinematography': 'John Seale', 'edited by': 'Carol Littleton', 'music by': 'James Newton Howard', 'productioncompanies': ['Castle Rock Entertainment', 'Village Roadshow Pictures', 'Kasdan Pictures', 'NPV Entertainment', 'WV Films II'], 'distributed by': 'Warner Bros. Pictures', 'release date': ['March\xa021,\xa02003(2003-03-21)'], 'running time': '134 minutes, [, 1, ]', 'country': 'United States', 'language': 'English', 'budget': '$68 million, [, 2, ]', 'box office': '$75.7 million, [, 3, ]'}
# synopsis                          Four young friends perform a heroic act — and ...
# opening_weekend                                                         $15,027,423
# percent_of_total_gross                                                        44.6%
# production_budget                 $68,000,000 (worldwide box office is 1.1 times...
# domestic_release_date                                              March 21st, 2003
# running_time                                                            133 minutes
# keywords                          Rescue , Body Horror , Possessed , Alien Invas...
# source                                            Based on Fiction Book/Short Story
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                       Science Fiction
# production_financing_companies    Village Roadshow Productions , Castle Rock Ent...
# production_countries                                         Canada , United States
# languages                                                                   English
# lead_ensemble_members                                                            []
# production_technical_credits      {'Director': ['Lawrence Kasdan'], 'Screenwrite...
# movie_url                         https://www.the-numbers.com/movie/Dreamcatcher...
# movie_title                                                            Dreamcatcher
# Name: 382, dtype: object
# ********
# synopsis                          Four young friends perform a heroic act — and ...
# opening_weekend                                                         $15,027,423
# percent_of_total_gross                                                        44.6%
# production_budget                 $68,000,000 (worldwide box office is 1.1 times...
# domestic_release_date                                              March 21st, 2003
# running_time                                                            133 minutes
# keywords                          Rescue , Body Horror , Possessed , Alien Invas...
# source                                            Based on Fiction Book/Short Story
# genre                                                                        Horror
# production_method                                                       Live Action
# creative_type                                                       Science Fiction
# production_financing_companies    Village Roadshow Productions , Castle Rock Ent...
# production_countries                                         Canada , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Morgan Freeman', 'role': ''}, {'ac...
# production_technical_credits      {'Director': ['Lawrence Kasdan'], 'Screenwrite...
# movie_url                         https://www.the-numbers.com/movie/Dreamcatcher...
# movie_title                                                            Dreamcatcher
# Name: 382, dtype: object
# Updated row 382
# -------------------------
# Runaway Jury 2003
# Updated row 387
# -------------------------
# The Italian Job 2003
# ...
# source                                            Based on Fiction Book/Short Story
# genre                                                                     Adventure
# production_method                                             Animation/Live Action
# creative_type                                                          Kids Fiction
# production_financing_companies                                                  NaN
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                 [{'actor': 'Zachary Levi', 'role': 'Harold'}]
# production_technical_credits      {'Director': ['Carlos Saldanha'], 'Screenwrite...
# movie_url                         https://www.the-numbers.com/movie/Harold-and-t...
# movie_title                                            Harold and the Purple Crayon
# Name: 4592, dtype: object
# ********
# synopsis                          Inside of his book, adventurous Harold can mak...
# opening_weekend                                                          $6,003,197
# percent_of_total_gross                                                        34.0%
# production_budget                 $40,000,000 (worldwide box office is 0.7 times...
# domestic_release_date                                              August 2nd, 2024
# running_time                                                             92 minutes
# keywords                                        Family Adventure , Development Hell
# source                                            Based on Fiction Book/Short Story
# genre                                                                     Adventure
# production_method                                             Animation/Live Action
# creative_type                                                          Kids Fiction
# production_financing_companies    [Columbia Pictures, Davis Entertainment, TSG E...
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                 [{'actor': 'Zachary Levi', 'role': 'Harold'}]
# production_technical_credits      {'Director': ['Carlos Saldanha'], 'Screenwrite...
# movie_url                         https://www.the-numbers.com/movie/Harold-and-t...
# movie_title                                            Harold and the Purple Crayon
# Name: 4592, dtype: object
# Updated row 4592
# -------------------------
# Updated row 4593
# -------------------------
# Updated row 4594
# -------------------------
# Lahn mah 2024
# Updated row 4595
# -------------------------
# Updated row 4596
# -------------------------
# Updated row 4597
# -------------------------
# Updated row 4598
# -------------------------
# Ainda Estou Aqui 2025
# Updated row 4600
# -------------------------
# Updated row 4601
# -------------------------
# The Movie Emperor (红毯先生) 2024
# Updated row 4602
# -------------------------
# Updated row 4603
# -------------------------
# The Chosen: Season 4 Episodes 1-3 2024
# Updated row 4604
# -------------------------
# Hijack 1971 (하이재킹) 2024
# Updated row 4605
# -------------------------
# Updated row 4606
# -------------------------
# Updated row 4607
# -------------------------
# Maria 2024
# {'directed by': 'Pablo Larraín', 'written by': 'Steven Knight', 'produced by': ['Juan de Dios Larraín', 'Jonas Dornbach', 'Lorenzo Mieli', 'Pablo Larraín', 'Janine Jackowski', 'Maren Ade', 'Simone Gattoni'], 'starring': ['Angelina Jolie', 'Pierfrancesco Favino', 'Alba Rohrwacher', 'Haluk Bilginer', 'Kodi Smit-McPhee'], 'cinematography': 'Edward Lachman', 'edited by': 'Sofía Subercaseaux', 'productioncompanies': ['Fremantle', 'The Apartment Pictures', 'Komplizen Film', 'Fabula', 'FilmNation Entertainment'], 'distributed by': ['01 Distribution(Italy)', 'StudioCanal(United Kingdom, Ireland, Germany and Poland)', 'Netflix(United States)'], 'release dates': ['August\xa029,\xa02024(2024-08-29)(Venice)', 'November\xa027,\xa02024(2024-11-27)(United States)', 'January\xa01,\xa02025(2025-01-01)(Italy)', 'February\xa06,\xa02025(2025-02-06)(Germany)'], 'running time': '124 minutes', 'countries': ['Italy', 'Germany', 'United Kingdom', 'United States'], 'languages': ['English', 'Greek'], 'box office': '$23.7 million, [, 1, ]'}
# synopsis                          Maria Callas, the world's greatest opera singe...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                           November 27th, 2024
# running_time                                                            121 minutes
# keywords                          1970s , Opera , Biographical Drama , Venice Fi...
# source                                                    Based on Real Life Events
# genre                                                                         Drama
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies                                                  NaN
# production_countries                                        Chile , Germany , Italy
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Angelina Jolie', 'role': 'Maria Ca...
# production_technical_credits      {'Director': ['Pablo Larrain'], 'Screenwriter'...
# movie_url                         https://www.the-numbers.com/movie/Maria-(2024-...
# movie_title                                                                   Maria
# Name: 4609, dtype: object
# ********
# synopsis                          Maria Callas, the world's greatest opera singe...
# opening_weekend                                                                 NaN
# percent_of_total_gross                                                          NaN
# production_budget                                                               NaN
# domestic_release_date                                           November 27th, 2024
# running_time                                                            121 minutes
# keywords                          1970s , Opera , Biographical Drama , Venice Fi...
# source                                                    Based on Real Life Events
# genre                                                                         Drama
# production_method                                                       Live Action
# creative_type                                                         Dramatization
# production_financing_companies    [Fremantle, The Apartment Pictures, Komplizen ...
# production_countries                                        Chile , Germany , Italy
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Angelina Jolie', 'role': 'Maria Ca...
# production_technical_credits      {'Director': ['Pablo Larrain'], 'Screenwriter'...
# movie_url                         https://www.the-numbers.com/movie/Maria-(2024-...
# movie_title                                                                   Maria
# Name: 4609, dtype: object
# Updated row 4609
# -------------------------
# Thelma 2024
# {'directed by': 'Josh Margolin', 'written by': 'Josh Margolin', 'produced by': ['Zoë Worth', 'Chris Kaye', 'Nicholas Weinstock', 'Benjamin Simpson', 'Karl Spoerri', 'Viviana Vezzani'], 'starring': ['June Squibb', 'Fred Hechinger', 'Richard Roundtree', 'Clark Gregg', 'Parker Posey', 'Malcolm McDowell'], 'cinematography': 'David Bolen', 'edited by': 'Josh Margolin', 'music by': 'Nick Chuba', 'productioncompany': 'Bandwagon', 'distributed by': ['Magnolia Pictures(United States and Canada)', 'Universal Pictures(International)[1]'], 'release dates': ['January\xa018,\xa02024(2024-01-18)(Sundance)', 'June\xa021,\xa02024(2024-06-21)(United States)'], 'running time': '98 minutes, [, 2, ]', 'country': 'United States', 'language': 'English', 'budget': '$3 million', 'box office': '$12.6 million, [, 3, ], [, 1, ]'}
# synopsis                          When 93-year-old Thelma Post gets duped by a p...
# opening_weekend                                                          $2,302,222
# percent_of_total_gross                                                        25.6%
# production_budget                                                               NaN
# domestic_release_date                                               June 21st, 2024
# running_time                                                             97 minutes
# keywords                          Action Comedy , Crime , Autumn Years , Confide...
# source                                                          Original Screenplay
# genre                                                                        Action
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Magnolia Pictures , Zurich Avenue , Invention ...
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                  [{'actor': 'June Squibb', 'role': 'Thelma'}]
# production_technical_credits      {'Director': ['Josh Margolin'], 'Screenwriter'...
# movie_url                         https://www.the-numbers.com/movie/Thelma-(2024...
# movie_title                                                                  Thelma
# Name: 4610, dtype: object
# ********
# synopsis                          When 93-year-old Thelma Post gets duped by a p...
# opening_weekend                                                          $2,302,222
# percent_of_total_gross                                                        25.6%
# production_budget                 $3,000,000 (worldwide box office is 4.2 times ...
# domestic_release_date                                               June 21st, 2024
# running_time                                                             97 minutes
# keywords                          Action Comedy , Crime , Autumn Years , Confide...
# source                                                          Original Screenplay
# genre                                                                        Action
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Magnolia Pictures , Zurich Avenue , Invention ...
# production_countries                                                  United States
# languages                                                                   English
# lead_ensemble_members                  [{'actor': 'June Squibb', 'role': 'Thelma'}]
# production_technical_credits      {'Director': ['Josh Margolin'], 'Screenwriter'...
# movie_url                         https://www.the-numbers.com/movie/Thelma-(2024...
# movie_title                                                                  Thelma
# Name: 4610, dtype: object
# Updated row 4610
# -------------------------
# Kinds of Kindness 2024
# Updated row 4611
# -------------------------
# Le Dernier Jaguar 2025
# Updated row 4613
# -------------------------
# A Legend (传说) 2025
# Updated row 4614
# -------------------------
# Love Lies Bleeding 2024
# {'directed by': 'Rose Glass', 'written by': ['Rose Glass', 'Weronika Tofilska'], 'produced by': ['Andrea Cornwell', 'Oliver Kassman'], 'starring': ['Kristen Stewart', "Katy O'Brian", 'Jena Malone', 'Anna Baryshnikov', 'Dave Franco', 'Ed Harris'], 'cinematography': 'Ben Fordesman', 'edited by': 'Mark Towns', 'music by': 'Clint Mansell', 'productioncompanies': ['A24[1][2][3]', 'Film4', 'Escape Plan', 'Lobo Films'], 'distributed by': ['A24 (United States)', 'Lionsgate(United Kingdom)'], 'release dates': ['January\xa020,\xa02024(2024-01-20)(Sundance)', 'March\xa08,\xa02024(2024-03-08)(United States)', 'May\xa03,\xa02024(2024-05-03)(United Kingdom)'], 'running time': '104 minutes, [, 4, ]', 'countries': ['United Kingdom', 'United States'], 'language': 'English', 'box office': '$12.8 million, [, 5, ], [, 6, ]'}
# synopsis                          Reclusive gym manager Lou falls hard for Jacki...
# opening_weekend                                                            $150,765
# percent_of_total_gross                                                         1.9%
# production_budget                                                               NaN
# domestic_release_date                                               March 8th, 2024
# running_time                                                            104 minutes
# keywords                          Romance , Bodybuilders , LGBTQ+ , Filmed in Al...
# source                                                          Original Screenplay
# genre                                                             Thriller/Suspense
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Lobo Films , A24 , Film 4 , Escape Plan Produc...
# production_countries                                 United Kingdom , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Kristen Stewart', 'role': 'Lou'}, ...
# production_technical_credits      {'Director': ['Rose Glass'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Love-Lies-Bl...
# movie_title                                                      Love Lies Bleeding
# Name: 4615, dtype: object
# ********
# synopsis                          Reclusive gym manager Lou falls hard for Jacki...
# opening_weekend                                                            $150,765
# percent_of_total_gross                                                         1.9%
# production_budget                                                               NaN
# domestic_release_date                                               March 8th, 2024
# running_time                                                            104 minutes
# keywords                          Romance , Bodybuilders , LGBTQ+ , Filmed in Al...
# source                                                          Original Screenplay
# genre                                                             Thriller/Suspense
# production_method                                                       Live Action
# creative_type                                                  Contemporary Fiction
# production_financing_companies    Lobo Films , A24 , Film 4 , Escape Plan Produc...
# production_countries                                 United Kingdom , United States
# languages                                                                   English
# lead_ensemble_members             [{'actor': 'Kristen Stewart', 'role': 'Lou'}, ...
# production_technical_credits      {'Director': ['Rose Glass'], 'Screenwriter': [...
# movie_url                         https://www.the-numbers.com/movie/Love-Lies-Bl...
# movie_title                                                      Love Lies Bleeding
# Name: 4615, dtype: object
# Updated row 4615
# -------------------------
# Am I Racist? 2024
# Updated row 4616
# -------------------------
# Lee 2024
# Updated row 4617
# -------------------------
# Megalopolis 2024
# Updated row 4618
# -------------------------
# Updated row 4619
# -------------------------
# Updated row 4620
# -------------------------
# Updated row 4621
# -------------------------
# Bonhoeffer: Pastor. Spy. Assassin 2024
# Updated row 4622
# -------------------------
# Article 370 2024
# Updated row 4623
# -------------------------

# %% [markdown]
# ## Saving Our Fully Enriched Dataset
#
# With both TMDB and Wikipedia data incorporated, our movie dataset is now much more complete. We'll save the final enriched dataset to a CSV file, ready for analysis or further processing. The combined data from multiple sources gives us a rich set of attributes for each movie, enabling more comprehensive analysis of trends in the film industry from 2000 to 2025.

# %%
df.to_csv("updated_movies2.csv", index=False)
